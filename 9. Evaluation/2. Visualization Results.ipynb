# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Compare Results: RF, AdaBoost and XGBoost

# %%
res = pd.read_csv('../Results/model_Result_final.csv',index_col=0)

res.set_index('Model', inplace=True)

res.sort_values(by='Recall',ascending=False)
# Out:
#                                              Accuracy   Average  F1 Score  \
# Model
# Random Forest (n=35) with OOB_12             0.995225  0.219926  0.387387
# XGB with OOB4                                0.989835  0.116779  0.229028
# XGBoost Classifier                           0.994347  0.188779  0.345528
# Ensemble Classifier with best model(recall)  0.996594  0.280000  0.467033
# Ensemble Classifier with All Models          0.996840  0.290000  0.485714
# Random Forest All Features                   0.996647  0.277870  0.467967
# Random Forest (n=27) with OOB_9              0.993908  0.174253  0.326214
# AdaBoost Simple Classifier                   0.992732  0.150212  0.288660
# AdaBoost (n=15) with OOB_10                  0.993171  0.155313  0.299099
#
#                                              Kappa Cohen  Precision    Recall  \
# Model
# Random Forest (n=35) with OOB_12                0.385752   0.247839  0.886598
# ...
